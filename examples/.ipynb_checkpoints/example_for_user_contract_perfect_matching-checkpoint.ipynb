# %%
load("~/.sage/user_definitions/user_graph_contract.sage")
    
n=6
for g in graphs.nauty_geng(options=f'-c {n} {n-1}:{n-1}'):
    h=contract_perfect_matching(g)
    show(h)
# Out:
# No perfect matching found. Returning original graph.
# Graphics object consisting of 12 graphics primitives
# No perfect matching found. Returning original graph.
# Graphics object consisting of 12 graphics primitives
# No perfect matching found. Returning original graph.
# Graphics object consisting of 12 graphics primitives
# No perfect matching found. Returning original graph.
# Graphics object consisting of 12 graphics primitives
# Perfect matching found.The original graph and the contracted graph is:.
# Graphics object consisting of 17 graphics primitives
# Perfect matching found.The original graph and the contracted graph is:.
# Graphics object consisting of 17 graphics primitives
